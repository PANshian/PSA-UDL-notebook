# %% [markdown]
# <a href="https://colab.research.google.com/github/PANshian/PSA-UDL-notebook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-law0ojei
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-law0ojei
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=ea1e6d0d0d588d6b186e383f105013f1216755dc65b3437729738b1a01d93520
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m7yh3q9w/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10

# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential). Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
    def __init__(self, input_size, output_size, hidden_size=100):
        super(ResidualNetwork, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, hidden_size)
        self.linear4 = nn.Linear(hidden_size, output_size)
        print("Initialized MLPBase model with {} parameters".format(self.count_params()))

    def count_params(self):
        return sum([p.view(-1).shape[0] for p in self.parameters()])

    # TODO -- Add residual connections to this model
    # The order of operations within each block should similar to figure 11.5b
    # ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
    # Replace this function
    def forward(self, x):
        # 第一层：linear1 + ReLU（完全保留原始逻辑）
        h1 = self.linear1(x).relu()

        # 第一个残差块：ReLU+linear2，添加残差连接（h1 → h2的恒等映射分支）
        h2 = self.linear2(h1).relu()
        h2 = h2 + h1  # ✅ 残差连接：将输入h1加到输出h2上

        # 第二个残差块：ReLU+linear3，添加残差连接（h2 → h3的恒等映射分支）
        h3 = self.linear3(h2).relu()
        h3 = h3 + h2  # ✅ 残差连接：将输入h2加到输出h3上

        # 最终输出层：linear4（完全保留原始逻辑）
        return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.602295, train error 62.47,  val loss 1.706650, percent error 67.80
# Epoch     1, train loss 1.273759, train error 47.35,  val loss 1.419723, percent error 55.60
# Epoch     2, train loss 1.041619, train error 37.45,  val loss 1.236059, percent error 47.40
# Epoch     3, train loss 0.932097, train error 34.80,  val loss 1.176992, percent error 44.30
# Epoch     4, train loss 0.845284, train error 30.82,  val loss 1.176548, percent error 45.30
# Epoch     5, train loss 0.759068, train error 27.90,  val loss 1.185969, percent error 45.30
# Epoch     6, train loss 0.653726, train error 22.72,  val loss 1.129459, percent error 42.60
# Epoch     7, train loss 0.589114, train error 21.15,  val loss 1.102892, percent error 40.10
# Epoch     8, train loss 0.522419, train error 18.07,  val loss 1.126116, percent error 40.10
# Epoch     9, train loss 0.466740, train error 15.43,  val loss 1.182524, percent error 39.20
# Epoch    10, train loss 0.455556, train error 16.28,  val loss 1.276820, percent error 41.80
# Epoch    11, train loss 0.394028, train error 13.43,  val loss 1.211129, percent error 39.70
# Epoch    12, train loss 0.328279, train error 11.35,  val loss 1.232109, percent error 38.40
# Epoch    13, train loss 0.281274, train error 9.38,  val loss 1.304056, percent error 39.30
# Epoch    14, train loss 0.207003, train error 6.38,  val loss 1.287414, percent error 37.40
# Epoch    15, train loss 0.198253, train error 5.88,  val loss 1.352780, percent error 37.40
# Epoch    16, train loss 0.211591, train error 7.18,  val loss 1.463354, percent error 37.10
# Epoch    17, train loss 0.128096, train error 3.55,  val loss 1.420936, percent error 37.40
# Epoch    18, train loss 0.137039, train error 4.00,  val loss 1.527908, percent error 38.80
# Epoch    19, train loss 0.138072, train error 4.43,  val loss 1.609195, percent error 38.40
# Epoch    20, train loss 0.045419, train error 0.28,  val loss 1.430954, percent error 35.20
# Epoch    21, train loss 0.027981, train error 0.00,  val loss 1.482787, percent error 35.20
# Epoch    22, train loss 0.022736, train error 0.03,  val loss 1.487635, percent error 35.00
# Epoch    23, train loss 0.019356, train error 0.00,  val loss 1.505364, percent error 35.10
# Epoch    24, train loss 0.017044, train error 0.00,  val loss 1.523810, percent error 34.70
# Epoch    25, train loss 0.015387, train error 0.00,  val loss 1.547747, percent error 34.50
# Epoch    26, train loss 0.014104, train error 0.00,  val loss 1.575017, percent error 34.50
# Epoch    27, train loss 0.012937, train error 0.00,  val loss 1.587599, percent error 35.00
# Epoch    28, train loss 0.012150, train error 0.00,  val loss 1.612183, percent error 34.80
# Epoch    29, train loss 0.011057, train error 0.00,  val loss 1.615726, percent error 34.40
# Epoch    30, train loss 0.010470, train error 0.00,  val loss 1.638142, percent error 34.80
# Epoch    31, train loss 0.009824, train error 0.00,  val loss 1.650883, percent error 35.10
# Epoch    32, train loss 0.009180, train error 0.00,  val loss 1.665535, percent error 35.10
# Epoch    33, train loss 0.008664, train error 0.00,  val loss 1.674201, percent error 35.00
# Epoch    34, train loss 0.008415, train error 0.00,  val loss 1.688556, percent error 34.90
# Epoch    35, train loss 0.007830, train error 0.00,  val loss 1.700003, percent error 34.70
# Epoch    36, train loss 0.007442, train error 0.00,  val loss 1.715201, percent error 35.00
# Epoch    37, train loss 0.007106, train error 0.00,  val loss 1.723610, percent error 34.80
# Epoch    38, train loss 0.006809, train error 0.00,  val loss 1.736202, percent error 34.80
# Epoch    39, train loss 0.006533, train error 0.00,  val loss 1.741055, percent error 34.70
# Epoch    40, train loss 0.006366, train error 0.00,  val loss 1.748664, percent error 34.80
# Epoch    41, train loss 0.006233, train error 0.00,  val loss 1.753224, percent error 34.70
# Epoch    42, train loss 0.006124, train error 0.00,  val loss 1.758048, percent error 34.80
# Epoch    43, train loss 0.005998, train error 0.00,  val loss 1.762994, percent error 34.80
# Epoch    44, train loss 0.005884, train error 0.00,  val loss 1.767826, percent error 34.80
# Epoch    45, train loss 0.005779, train error 0.00,  val loss 1.772798, percent error 34.90
# Epoch    46, train loss 0.005680, train error 0.00,  val loss 1.776236, percent error 35.00
# Epoch    47, train loss 0.005571, train error 0.00,  val loss 1.781043, percent error 35.00
# Epoch    48, train loss 0.005470, train error 0.00,  val loss 1.785076, percent error 35.00
# Epoch    49, train loss 0.005378, train error 0.00,  val loss 1.789974, percent error 34.80
# Epoch    50, train loss 0.005285, train error 0.00,  val loss 1.794179, percent error 35.00
# Epoch    51, train loss 0.005195, train error 0.00,  val loss 1.798444, percent error 34.90
# Epoch    52, train loss 0.005118, train error 0.00,  val loss 1.801281, percent error 35.10
# Epoch    53, train loss 0.005023, train error 0.00,  val loss 1.805196, percent error 34.90
# Epoch    54, train loss 0.004947, train error 0.00,  val loss 1.809723, percent error 35.10
# Epoch    55, train loss 0.004864, train error 0.00,  val loss 1.813098, percent error 35.00
# Epoch    56, train loss 0.004787, train error 0.00,  val loss 1.817550, percent error 35.00
# Epoch    57, train loss 0.004717, train error 0.00,  val loss 1.820673, percent error 34.90
# Epoch    58, train loss 0.004646, train error 0.00,  val loss 1.824111, percent error 34.80
# Epoch    59, train loss 0.004572, train error 0.00,  val loss 1.828979, percent error 35.00
# Epoch    60, train loss 0.004535, train error 0.00,  val loss 1.830503, percent error 34.90
# Epoch    61, train loss 0.004501, train error 0.00,  val loss 1.832783, percent error 34.90
# Epoch    62, train loss 0.004468, train error 0.00,  val loss 1.833777, percent error 35.00
# Epoch    63, train loss 0.004436, train error 0.00,  val loss 1.835928, percent error 35.00
# Epoch    64, train loss 0.004402, train error 0.00,  val loss 1.838172, percent error 34.90
# Epoch    65, train loss 0.004371, train error 0.00,  val loss 1.840080, percent error 34.90
# Epoch    66, train loss 0.004339, train error 0.00,  val loss 1.840756, percent error 34.90
# Epoch    67, train loss 0.004309, train error 0.00,  val loss 1.843104, percent error 34.90
# Epoch    68, train loss 0.004278, train error 0.00,  val loss 1.845761, percent error 35.00
# Epoch    69, train loss 0.004248, train error 0.00,  val loss 1.846526, percent error 35.00
# Epoch    70, train loss 0.004218, train error 0.00,  val loss 1.848280, percent error 34.90
# Epoch    71, train loss 0.004188, train error 0.00,  val loss 1.850619, percent error 34.90
# Epoch    72, train loss 0.004159, train error 0.00,  val loss 1.851695, percent error 35.00
# Epoch    73, train loss 0.004130, train error 0.00,  val loss 1.853626, percent error 34.90
# Epoch    74, train loss 0.004102, train error 0.00,  val loss 1.855261, percent error 34.90
# Epoch    75, train loss 0.004074, train error 0.00,  val loss 1.856900, percent error 34.90
# Epoch    76, train loss 0.004046, train error 0.00,  val loss 1.857852, percent error 34.90
# Epoch    77, train loss 0.004019, train error 0.00,  val loss 1.860131, percent error 34.90
# Epoch    78, train loss 0.003992, train error 0.00,  val loss 1.861398, percent error 34.80
# Epoch    79, train loss 0.003964, train error 0.00,  val loss 1.863499, percent error 34.90
# Epoch    80, train loss 0.003951, train error 0.00,  val loss 1.864396, percent error 34.90
# Epoch    81, train loss 0.003938, train error 0.00,  val loss 1.864673, percent error 34.80
# Epoch    82, train loss 0.003924, train error 0.00,  val loss 1.865673, percent error 34.90
# Epoch    83, train loss 0.003912, train error 0.00,  val loss 1.866186, percent error 34.90
# Epoch    84, train loss 0.003899, train error 0.00,  val loss 1.867031, percent error 34.80
# Epoch    85, train loss 0.003886, train error 0.00,  val loss 1.867949, percent error 34.80
# Epoch    86, train loss 0.003873, train error 0.00,  val loss 1.868802, percent error 34.80
# Epoch    87, train loss 0.003860, train error 0.00,  val loss 1.869089, percent error 34.80
# Epoch    88, train loss 0.003848, train error 0.00,  val loss 1.870600, percent error 34.80
# Epoch    89, train loss 0.003835, train error 0.00,  val loss 1.871050, percent error 34.80
# Epoch    90, train loss 0.003823, train error 0.00,  val loss 1.871841, percent error 34.80
# Epoch    91, train loss 0.003811, train error 0.00,  val loss 1.872567, percent error 34.80
# Epoch    92, train loss 0.003798, train error 0.00,  val loss 1.873106, percent error 34.80
# Epoch    93, train loss 0.003787, train error 0.00,  val loss 1.873719, percent error 34.80
# Epoch    94, train loss 0.003774, train error 0.00,  val loss 1.874932, percent error 34.80
# Epoch    95, train loss 0.003762, train error 0.00,  val loss 1.875526, percent error 34.80
# Epoch    96, train loss 0.003750, train error 0.00,  val loss 1.876179, percent error 34.90
# Epoch    97, train loss 0.003738, train error 0.00,  val loss 1.876779, percent error 34.80
# Epoch    98, train loss 0.003726, train error 0.00,  val loss 1.878006, percent error 34.90
# Epoch    99, train loss 0.003715, train error 0.00,  val loss 1.878864, percent error 34.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
